# %%
from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://id.nlm.nih.gov/mesh/sparql")
sparql.setQuery("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX meshv: <http://id.nlm.nih.gov/mesh/vocab#>
PREFIX mesh: <http://id.nlm.nih.gov/mesh/>
PREFIX mesh2015: <http://id.nlm.nih.gov/mesh/2015/>
PREFIX mesh2016: <http://id.nlm.nih.gov/mesh/2016/>
PREFIX mesh2017: <http://id.nlm.nih.gov/mesh/2017/>
PREFIX mesh2018: <http://id.nlm.nih.gov/mesh/2018/>

SELECT DISTINCT ?p
FROM <http://id.nlm.nih.gov/mesh>
WHERE {
  # ?s ?p ?o .
} 
ORDER BY ?p
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
print(results)

for result in results["results"]["bindings"]:
    print(result["p"]["value"])
# Out:
# {'head': {'vars': ['p']}, 'results': {'bindings': [{'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#abbreviation'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#active'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#allowableQualifier'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#altLabel'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#annotation'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#broaderConcept'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#broaderDescriptor'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#broaderQualifier'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#casn1_label'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#concept'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#considerAlso'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#dateCreated'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#dateEstablished'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#dateRevised'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#entryVersion'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#frequency'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#hasDescriptor'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#hasQualifier'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#historyNote'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#identifier'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#indexerConsiderAlso'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#lastActiveYear'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#lexicalTag'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#mappedTo'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#narrowerConcept'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#nlmClassificationNumber'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#note'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#onlineNote'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#parentTreeNumber'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#pharmacologicalAction'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#prefLabel'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#preferredConcept'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#preferredMappedTo'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#preferredTerm'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#previousIndexing'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#publicMeSHNote'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#registryNumber'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#relatedConcept'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#relatedRegistryNumber'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#scopeNote'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#seeAlso'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#sortVersion'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#source'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#term'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#thesaurusID'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#treeNumber'}}, {'p': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/vocab#useInstead'}}, {'p': {'type': 'uri', 'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}} ...
# http://id.nlm.nih.gov/mesh/vocab#abbreviation
# http://id.nlm.nih.gov/mesh/vocab#active
# http://id.nlm.nih.gov/mesh/vocab#allowableQualifier
# http://id.nlm.nih.gov/mesh/vocab#altLabel
# http://id.nlm.nih.gov/mesh/vocab#annotation
# http://id.nlm.nih.gov/mesh/vocab#broaderConcept
# http://id.nlm.nih.gov/mesh/vocab#broaderDescriptor
# http://id.nlm.nih.gov/mesh/vocab#broaderQualifier
# http://id.nlm.nih.gov/mesh/vocab#casn1_label
# http://id.nlm.nih.gov/mesh/vocab#concept
# http://id.nlm.nih.gov/mesh/vocab#considerAlso
# http://id.nlm.nih.gov/mesh/vocab#dateCreated
# http://id.nlm.nih.gov/mesh/vocab#dateEstablished
# http://id.nlm.nih.gov/mesh/vocab#dateRevised
# http://id.nlm.nih.gov/mesh/vocab#entryVersion
# http://id.nlm.nih.gov/mesh/vocab#frequency
# http://id.nlm.nih.gov/mesh/vocab#hasDescriptor
# http://id.nlm.nih.gov/mesh/vocab#hasQualifier
# http://id.nlm.nih.gov/mesh/vocab#historyNote
# http://id.nlm.nih.gov/mesh/vocab#identifier
# http://id.nlm.nih.gov/mesh/vocab#indexerConsiderAlso
# http://id.nlm.nih.gov/mesh/vocab#lastActiveYear
# http://id.nlm.nih.gov/mesh/vocab#lexicalTag
# http://id.nlm.nih.gov/mesh/vocab#mappedTo
# http://id.nlm.nih.gov/mesh/vocab#narrowerConcept
# http://id.nlm.nih.gov/mesh/vocab#nlmClassificationNumber
# http://id.nlm.nih.gov/mesh/vocab#note
# http://id.nlm.nih.gov/mesh/vocab#onlineNote
# http://id.nlm.nih.gov/mesh/vocab#parentTreeNumber
# http://id.nlm.nih.gov/mesh/vocab#pharmacologicalAction
# http://id.nlm.nih.gov/mesh/vocab#prefLabel
# http://id.nlm.nih.gov/mesh/vocab#preferredConcept
# http://id.nlm.nih.gov/mesh/vocab#preferredMappedTo
# http://id.nlm.nih.gov/mesh/vocab#preferredTerm
# http://id.nlm.nih.gov/mesh/vocab#previousIndexing
# http://id.nlm.nih.gov/mesh/vocab#publicMeSHNote
# http://id.nlm.nih.gov/mesh/vocab#registryNumber
# http://id.nlm.nih.gov/mesh/vocab#relatedConcept
# http://id.nlm.nih.gov/mesh/vocab#relatedRegistryNumber
# http://id.nlm.nih.gov/mesh/vocab#scopeNote
# http://id.nlm.nih.gov/mesh/vocab#seeAlso
# http://id.nlm.nih.gov/mesh/vocab#sortVersion
# http://id.nlm.nih.gov/mesh/vocab#source
# http://id.nlm.nih.gov/mesh/vocab#term
# http://id.nlm.nih.gov/mesh/vocab#thesaurusID
# http://id.nlm.nih.gov/mesh/vocab#treeNumber
# http://id.nlm.nih.gov/mesh/vocab#useInstead
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# http://www.w3.org/2000/01/rdf-schema#label

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://id.nlm.nih.gov/mesh/sparql")
sparql.setQuery("""
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX meshv: <http://id.nlm.nih.gov/mesh/vocab#>
PREFIX mesh: <http://id.nlm.nih.gov/mesh/>
PREFIX mesh2015: <http://id.nlm.nih.gov/mesh/2015/>
PREFIX mesh2016: <http://id.nlm.nih.gov/mesh/2016/>
PREFIX mesh2017: <http://id.nlm.nih.gov/mesh/2017/>
PREFIX mesh2018: <http://id.nlm.nih.gov/mesh/2018/>

SELECT distinct ?d ?dLabel 
FROM <http://id.nlm.nih.gov/mesh>
WHERE {
  # ?d meshv:allowableQualifier ?q .
  # ?q rdfs:label 'adverse effects'@en . 
  # ?d rdfs:label ?dLabel . 
} 
ORDER BY ?dLabel
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
print(results)

for result in results["results"]["bindings"]:
    print(result["dLabel"]["value"])
# Out:
# {'head': {'vars': ['d', 'dLabel']}, 'results': {'bindings': [{'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D008455'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '(4-(m-Chlorophenylcarbamoyloxy)-2-butynyl)trimethylammonium Chloride'}}, {'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D014013'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '1,2-Dihydroxybenzene-3,5-Disulfonic Acid Disodium Salt'}}, {'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D019813'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '1,2-Dimethylhydrazine'}}, {'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D015060'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '1,2-Dipalmitoylphosphatidylcholine'}}, {'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D015061'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '1,4-alpha-Glucan Branching Enzyme'}}, {'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D019307'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '1-(5-Isoquinolinesulfonyl)-2-Methylpiperazine'}}, {'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D051103'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '1-Acylglycerol-3-Phosphate O-Acyltransferase'}}, {'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D008243'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '1-Acylglycerophosphocholine O-Acyltransferase'}}, {'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D043203'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '1-Alkyl-2-acetylglycerophosphocholine Esterase'}}, {'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D020001'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '1-Butanol'}}, {'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D015055'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '1-Carboxyglutamic Acid'}}, {'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D017485'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '1-Deoxynojirimycin'}}, {'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D015056'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '1-Methyl-3-isobutylxanthine'}}, {'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D015632'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '1-Methyl-4-phenyl-1,2,3,6-tetrahydropyridine'}}, {'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D015655'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '1-Methyl-4-phenylpyridinium'}}, {'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D015057'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '1-Naphthylamine'}}, {'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D015058'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '1-Naphthylisothiocyanate'}}, {'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D020003'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '1-Octanol'}}, {'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D019870'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '1-Phosphatidylinositol 4-Kinase'}}, {'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D000433'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '1-Propanol'}}, {'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D050842'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '1-Pyrroline-5-Carboxylate Dehydrogenase'}}, {'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D015059'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '1-Sarcosine-8-Isoleucine Angiotensin II'}}, {'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D015062'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '11-Hydroxycorticosteroids'}}, {'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/D043205'}, 'dLabel': {'type': 'literal', 'xml:lang': 'en', 'value': '11-beta-Hydroxysteroid  ...
# (4-(m-Chlorophenylcarbamoyloxy)-2-butynyl)trimethylammonium Chloride
# 1,2-Dihydroxybenzene-3,5-Disulfonic Acid Disodium Salt
# 1,2-Dimethylhydrazine
# 1,2-Dipalmitoylphosphatidylcholine
# 1,4-alpha-Glucan Branching Enzyme
# 1-(5-Isoquinolinesulfonyl)-2-Methylpiperazine
# 1-Acylglycerol-3-Phosphate O-Acyltransferase
# 1-Acylglycerophosphocholine O-Acyltransferase
# 1-Alkyl-2-acetylglycerophosphocholine Esterase
# 1-Butanol
# 1-Carboxyglutamic Acid
# 1-Deoxynojirimycin
# 1-Methyl-3-isobutylxanthine
# 1-Methyl-4-phenyl-1,2,3,6-tetrahydropyridine
# 1-Methyl-4-phenylpyridinium
# 1-Naphthylamine
# 1-Naphthylisothiocyanate
# 1-Octanol
# 1-Phosphatidylinositol 4-Kinase
# 1-Propanol
# 1-Pyrroline-5-Carboxylate Dehydrogenase
# 1-Sarcosine-8-Isoleucine Angiotensin II
# 11-Hydroxycorticosteroids
# 11-beta-Hydroxysteroid Dehydrogenase Type 1
# 11-beta-Hydroxysteroid Dehydrogenase Type 2
# 11-beta-Hydroxysteroid Dehydrogenases
# 12-Hydroxy-5,8,10,14-eicosatetraenoic Acid
# 12E7 Antigen
# 14-3-3 Proteins
# 14-alpha Demethylase Inhibitors
# 15-Hydroxy-11 alpha,9 alpha-(epoxymethano)prosta-5,13-dienoic Acid
# 15-Oxoprostaglandin 13-Reductase
# 16,16-Dimethylprostaglandin E2
# 17-Hydroxycorticosteroids
# 17-Hydroxysteroid Dehydrogenases
# 17-Ketosteroids
# 17-alpha-Hydroxypregnenolone
# 17-alpha-Hydroxyprogesterone
# 18-Hydroxycorticosterone
# 18-Hydroxydesoxycorticosterone
# 19-Iodocholesterol
# 2',3'-Cyclic Nucleotide 3'-Phosphodiesterase
# 2',3'-Cyclic-Nucleotide Phosphodiesterases
# 2',5'-Oligoadenylate Synthetase
# 2,2'-Dipyridyl
# 2,3,4,5-Tetrahydro-7,8-dihydroxy-1-phenyl-1H-3-benzazepine
# 2,3-Diketogulonic Acid
# 2,3-Diphosphoglycerate
# 2,4,5-Trichlorophenoxyacetic Acid
# 2,4-Dichlorophenoxyacetic Acid
# 2,4-Dinitrophenol
# 2,5-Dimethoxy-4-Methylamphetamine
# 2,6-Dichloroindophenol
# 2-Acetolactate Mutase
# 2-Acetylaminofluorene
# 2-Amino-5-phosphonovalerate
# 2-Aminoadipate Transaminase
# 2-Aminoadipic Acid
# 2-Aminopurine
# 2-Chloroadenosine
# 2-Hydroxy-5-nitrobenzyl Bromide
# 2-Hydroxyphenethylamine
# 2-Hydroxypropyl-beta-cyclodextrin
# 2-Isopropylmalate Synthase
# 2-Methyl-4-chlorophenoxyacetic Acid
# 2-Naphthylamine
# 2-Oxoisovalerate Dehydrogenase (Acylating)
# 2-Propanol
# 2-Pyridinylmethylsulfinylbenzimidazoles
# 20-Hydroxysteroid Dehydrogenases
# 20-alpha-Dihydroprogesterone
# 20-alpha-Hydroxysteroid Dehydrogenase
# 24,25-Dihydroxyvitamin D 3
# 25-Hydroxyvitamin D 2
# 25-Hydroxyvitamin D3 1-alpha-Hydroxylase
# 2H-Benzo(a)quinolizin-2-ol, 2-Ethyl-1,3,4,6,7,11b-hexahydro-3-isobutyl-9,10-dimethoxy-
# 2S Albumins, Plant
# 3',5'-Cyclic-AMP Phosphodiesterases
# 3',5'-Cyclic-GMP Phosphodiesterases
# 3,3'-Diaminobenzidine
# 3,3'-Dichlorobenzidine
# 3,4-Dichloro-N-methyl-N-(2-(1-pyrrolidinyl)-cyclohexyl)-benzeneacetamide, (trans)-Isomer
# 3,4-Dihydroxyphenylacetic Acid
# 3,4-Methylenedioxyamphetamine
# 3-Deazauridine
# 3-Deoxy-7-Phosphoheptulonate Synthase
# 3-Hydroxyacyl CoA Dehydrogenases
# 3-Hydroxyacyl-CoA Dehydrogenase
# 3-Hydroxyanthranilate 3,4-Dioxygenase
# 3-Hydroxyanthranilic Acid
# 3-Hydroxybutyric Acid
# 3-Hydroxysteroid Dehydrogenases
# 3-Iodobenzylguanidine
# 3-Isopropylmalate Dehydrogenase
# 3-Mercaptopropionic Acid
# 3-Methoxy-4-hydroxyphenylethanol
# 3-Methyl-2-Oxobutanoate Dehydrogenase (Lipoamide)
# 3-O-Methylglucose
# 3-Oxo-5-alpha-Steroid 4-Dehydrogenase
# 3-Oxoacyl-(Acyl-Carrier-Protein) Reductase
# 3-Oxoacyl-(Acyl-Carrier-Protein) Synthase
# 3-Phosphoinositide-Dependent Protein Kinases
# 3-Phosphoshikimate 1-Carboxyvinyltransferase
# 3-Pyridinecarboxylic acid, 1,4-dihydro-2,6-dimethyl-5-nitro-4-(2-(trifluoromethyl)phenyl)-, Methyl ester
# 3-alpha-Hydroxysteroid Dehydrogenase (B-Specific)
# 4,4'-Diisothiocyanostilbene-2,2'-Disulfonic Acid
# 4,5-Dihydro-1-(3-(trifluoromethyl)phenyl)-1H-pyrazol-3-amine
# 4-(3-Butoxy-4-methoxybenzyl)-2-imidazolidinone
# 4-1BB Ligand
# 4-Acetamido-4'-isothiocyanatostilbene-2,2'-disulfonic Acid
# 4-Aminobenzoic Acid
# 4-Aminobutyrate Transaminase
# 4-Aminopyridine
# 4-Butyrolactone
# 4-Chloro-7-nitrobenzofurazan
# 4-Chloromercuribenzenesulfonate
# 4-Hydroxyaminoquinoline-1-oxide
# 4-Hydroxybenzoate-3-Monooxygenase
# 4-Hydroxycoumarins
# 4-Hydroxyphenylpyruvate Dioxygenase
# 4-Nitrophenylphosphatase
# 4-Nitroquinoline-1-oxide
# 4-Quinolones
# 5'-Nucleotidase
# 5,10-Methylenetetrahydrofolate Reductase (FADH2)
# 5,6-Dihydroxytryptamine
# 5,7-Dihydroxytryptamine
# 5,8,11,14-Eicosatetraynoic Acid
# 5-Amino-3-((5-nitro-2-furyl)vinyl)-1,2,4-oxadiazole
# 5-Aminolevulinate Synthetase
# 5-Hydroxytryptophan
# 5-Lipoxygenase-Activating Protein Inhibitors
# 5-Lipoxygenase-Activating Proteins
# 5-Methoxytryptamine
# 5-Methylcytosine
# 5-Methyltetrahydrofolate-Homocysteine S-Methyltransferase
# 5-alpha Reductase Inhibitors
# 5-alpha-Dihydroprogesterone
# 6-Aminonicotinamide
# 6-Cyano-7-nitroquinoxaline-2,3-dione
# 6-Ketoprostaglandin F1 alpha
# 6-Phytase
# 7,8-Dihydro-7,8-dihydroxybenzo(a)pyrene 9,10-oxide
# 7-Alkoxycoumarin O-Dealkylase
# 8,11,14-Eicosatrienoic Acid
# 8-Bromo Cyclic Adenosine Monophosphate
# 8-Hydroxy-2-(di-n-propylamino)tetralin
# 9,10-Dimethyl-1,2-benzanthracene
# A Kinase Anchor Proteins
# AAA Proteins
# ABO Blood-Group System
# AC133 Antigen
# ADAM Proteins
# ADAM10 Protein
# ADAM12 Protein
# ADAM17 Protein
# ADAMTS Proteins
# ADAMTS1 Protein
# ADAMTS13 Protein
# ADAMTS4 Protein
# ADAMTS5 Protein
# ADAMTS7 Protein
# ADAMTS9 Protein
# ADP Ribose Transferases
# ADP-Ribosylation Factor 1
# ADP-Ribosylation Factors
# ADP-ribosyl Cyclase
# ADP-ribosyl Cyclase 1
# AGAMOUS Protein, Arabidopsis
# AIDS Vaccines
# AMP Deaminase
# AMP-Activated Protein Kinases
# APOBEC Deaminases
# APOBEC-1 Deaminase
# APOBEC-3G Deaminase
# ARNTL Transcription Factors
# ATP Binding Cassette Subfamily B Member 11
# ATP Binding Cassette Transporter 1
# ATP Binding Cassette Transporter, Sub-Family A
# ATP Binding Cassette Transporter, Sub-Family A, Member 4
# ATP Binding Cassette Transporter, Sub-Family B
# ATP Binding Cassette Transporter, Sub-Family D
# ATP Binding Cassette Transporter, Sub-Family D, Member 1
# ATP Binding Cassette Transporter, Sub-Family G
# ATP Binding Cassette Transporter, Sub-Family G, Member 1
# ATP Binding Cassette Transporter, Sub-Family G, Member 2
# ATP Binding Cassette Transporter, Sub-Family G, Member 5
# ATP Binding Cassette Transporter, Sub-Family G, Member 8
# ATP Citrate (pro-S)-Lyase
# ATP Phosphoribosyltransferase
# ATP Synthetase Complexes
# ATP-Binding Cassette Sub-Family B Member 2
# ATP-Binding Cassette Transporters
# ATP-Binding Cassette, Sub-Family B, Member 1
# ATP-Binding Cassette, Sub-Family B, Member 3
# ATP-Dependent Endopeptidases
# ATP-Dependent Proteases
# ATPases Associated with Diverse Cellular Activities
# Abatacept
# Abdominal Wound Closure Techniques
# Abdominoplasty
# Abelmoschus
# Aberrometry
# Abies
# Abiraterone Acetate
# Ablation Techniques
# Abortifacient Agents
# Abortifacient Agents, Nonsteroidal
# Abortifacient Agents, Steroidal
# Abortion, Criminal
# Abortion, Eugenic
# Abortion, Induced
# Abortion, Legal
# Abortion, Therapeutic
# Abrin
# Abrus
# Abscisic Acid
# Absinthe
# Absorbable Implants
# Absorbent Pads
# Absorptiometry, Photon
# Abuse-Deterrent Formulations
# Acacia
# Acalypha
# Acanthaceae
# Acarbose
# Acaricides
# Acceleration
# Accelerometry
# Acebutolol
# Acecainide
# Acedapsone
# Acellular Dermis
# Acenaphthenes
# Acenocoumarol
# Acepromazine
# Acer
# Aceraceae
# Acetabuloplasty
# Acetaldehyde
# Acetaldehyde Dehydrogenase Inhibitors
# Acetals
# Acetamides
# Acetaminophen
# Acetanilides
# Acetate Kinase
# Acetate-CoA Ligase
# Acetates
# Acetazolamide
# Acetic Acid
# Acetic Anhydrides
# Acetoacetates
# Acetogenins
# Acetohexamide
# Acetoin
# Acetoin Dehydrogenase
# Acetolactate Synthase
# Acetone
# Acetonitriles
# Acetophenones
# Acetoxyacetylaminofluorene
# Acetrizoic Acid
# Acetyl Coenzyme A
# Acetyl-CoA C-Acetyltransferase
# Acetyl-CoA C-Acyltransferase
# Acetyl-CoA Carboxylase
# Acetyl-CoA Hydrolase
# Acetylcarnitine
# Acetylcholine
# Acetylcholine Release Inhibitors
# Acetylcholinesterase
# Acetylcysteine
# Acetyldigitoxins
# Acetyldigoxins
# Acetylene
# Acetylesterase
# Acetylgalactosamine
# Acetylglucosamine
# Acetylglucosaminidase
# Acetylmuramyl-Alanyl-Isoglutamine
# Acetylserotonin O-Methyltransferase
# Acetylthiocholine
# Acetyltransferases
# Achillea
# Achyranthes
# Achyrocline
# Acid Anhydride Hydrolases
# Acid Ceramidase
# Acid Etching, Dental
# Acid Phosphatase
# Acid Rain
# Acid Sensing Ion Channel Blockers
# Acid Sensing Ion Channels
# Acidic Glycosphingolipids
# Acids
# Acids, Acyclic
# Acids, Aldehydic
# Acids, Carbocyclic
# Acids, Heterocyclic
# Acids, Noncarboxylic
# Acidulated Phosphate Fluoride
# Acitretin
# Aclarubicin
# Aconitate Hydratase
# Aconitic Acid
# Aconitine
# Aconitum
# Acoraceae
# Acorus
# Acoustic Impedance Tests
# Acoustic Stimulation
# Acridine Orange
# Acridines
# Acridones
# Acriflavine
# Acrolein
# Acronine
# Acrosin
# Acrylamide
# Acrylamides
# Acrylates
# Acrylic Resins
# Acrylonitrile
# Actaea
# Actigraphy
# Actihaemyl
# Actin Capping Proteins
# Actin Depolymerizing Factors
# Actin-Related Protein 2
# Actin-Related Protein 2-3 Complex
# Actin-Related Protein 3
# Actinidia
# Actinidiaceae
# Actinin
# Actinium
# Actinoid Series Elements
# Actins
# Activated-Leukocyte Cell Adhesion Molecule
# Activating Transcription Factor 1
# Activating Transcription Factor 2
# Activating Transcription Factor 3
# Activating Transcription Factor 4
# Activating Transcription Factor 6
# Activating Transcription Factors
# Activator Appliances
# Activin Receptors
# Activin Receptors, Type I
# Activin Receptors, Type II
# Activins
# Actomyosin
# Actuarial Analysis
# Acupressure
# Acupuncture Analgesia
# Acupuncture Therapy
# Acupuncture, Ear
# Acute-Phase Proteins
# Acyclovir
# Acyl Carrier Protein
# Acyl Coenzyme A
# Acyl-Butyrolactones
# Acyl-Carrier Protein S-Acetyltransferase
# Acyl-Carrier Protein S-Malonyltransferase
# Acyl-CoA Dehydrogenase
# Acyl-CoA Dehydrogenase, Long-Chain
# Acyl-CoA Dehydrogenases
# Acyl-CoA Oxidase
# Acyltransferases
# Adalimumab
# Adamantane
# Adansonia
# Adapalene
# Adapalene, Benzoyl Peroxide Drug Combination
# Adaptive Clinical Trials as Topic
# Adaptor Protein Complex 1
# Adaptor Protein Complex 2
# Adaptor Protein Complex 3
# Adaptor Protein Complex 4
# Adaptor Protein Complex Subunits
# Adaptor Protein Complex alpha Subunits
# Adaptor Protein Complex beta Subunits
# Adaptor Protein Complex delta Subunits
# Adaptor Protein Complex gamma Subunits
# Adaptor Protein Complex mu Subunits
# Adaptor Protein Complex sigma Subunits
# Adaptor Proteins, Signal Transducing
# Adaptor Proteins, Vesicular Transport
# Adenine
# Adenine Nucleotide Translocator 1
# Adenine Nucleotide Translocator 2
# Adenine Nucleotide Translocator 3
# Adenine Nucleotides
# Adenine Phosphoribosyltransferase
# Adenoidectomy
# Adenomatous Polyposis Coli Protein
# Adenosine
# Adenosine A1 Receptor Agonists
# Adenosine A1 Receptor Antagonists
# Adenosine A2 Receptor Agonists
# Adenosine A2 Receptor Antagonists
# Adenosine A3 Receptor Agonists
# Adenosine A3 Receptor Antagonists
# Adenosine Deaminase
# Adenosine Deaminase Inhibitors
# Adenosine Diphosphate
# Adenosine Diphosphate Glucose
# Adenosine Diphosphate Ribose
# Adenosine Diphosphate Sugars
# Adenosine Kinase
# Adenosine Monophosphate
# Adenosine Phosphosulfate
# Adenosine Triphosphatases
# Adenosine Triphosphate
# Adenosine-5'-(N-ethylcarboxamide)
# Adenosylhomocysteinase
# Adenosylmethionine Decarboxylase
# Adenovirus E1 Proteins
# Adenovirus E1A Proteins
# Adenovirus E1B Proteins
# Adenovirus E2 Proteins
# Adenovirus E3 Proteins
# Adenovirus E4 Proteins
# Adenovirus Early Proteins
# Adenovirus Vaccines
# Adenylate Cyclase Toxin
# Adenylate Kinase
# Adenylosuccinate Lyase
# Adenylosuccinate Synthase
# Adenylyl Cyclase Inhibitors
# Adenylyl Cyclases
# Adenylyl Imidodiphosphate
# Adhesins, Bacterial
# Adhesins, Escherichia coli
# Adhesives
# Adiantum
# Adipates
# Adipokines
# Adiponectin
# Adjuvants, Anesthesia
# Adjuvants, Immunologic
# Adjuvants, Pharmaceutic
# Administration, Intranasal
# Administration, Intravenous
# Adonis
# Adoptive Transfer
# Adosterol
# Adoxaceae
# Adrenal Cortex Function Tests
# Adrenal Cortex Hormones
# Adrenalectomy
# Adrenergic Agents
# Adrenergic Agonists
# Adrenergic Antagonists
# Adrenergic Uptake Inhibitors
# Adrenergic alpha-1 Receptor Agonists
# Adrenergic alpha-1 Receptor Antagonists
# Adrenergic alpha-2 Receptor Agonists
# Adrenergic alpha-2 Receptor Antagonists
# Adrenergic alpha-Agonists
# Adrenergic alpha-Antagonists
# Adrenergic beta-1 Receptor Agonists
# Adrenergic beta-1 Receptor Antagonists
# Adrenergic beta-2 Receptor Agonists
# Adrenergic beta-2 Receptor Antagonists
# Adrenergic beta-3 Receptor Agonists
# Adrenergic beta-3 Receptor Antagonists
# Adrenergic beta-Agonists
# Adrenergic beta-Antagonists
# Adrenochrome
# Adrenocorticotropic Hormone
# Adrenodoxin
# Adrenomedullin
# Advanced Cardiac Life Support
# Advanced Oxidation Protein Products
# Aegle
# Aequorin
# Aerosol Propellants
# Aerosols
# Aesculus
# Affinity Labels
# Aflatoxin B1
# Aflatoxin M1
# Aflatoxins
# Agar
# Agastache
# Agatoxins
# Agave
# Agent Orange
# Ageratina
# Ageratum
# Agglutination Tests
# Agglutinins
# Aggrecans
# Aglaia
# Agmatine
# Agouti Signaling Protein
# Agouti-Related Protein
# Agrimonia
# Agrin
# Agrochemicals
# Agropyron
# Agrostemma
# Agrostis
# Ailanthus
# Air Abrasion, Dental
# Air Bags
# Air Conditioning
# Air Filters
# Air Pollutants
# Air Pollutants, Occupational
# Air Pollutants, Radioactive
# Air Pollution
# Air Pollution, Indoor
# Air Pollution, Radioactive
# Airway Extubation
# Airway Management
# Aizoaceae
# Ajmaline
# Ajuga
# Alamethicin
# Alangiaceae
# Alanine
# Alanine Dehydrogenase
# Alanine Racemase
# Alanine Transaminase
# Alanine-tRNA Ligase
# Alarmins
# Albendazole
# Albizzia
# Albumin-Bound Paclitaxel
# Albumins
# Albuterol
# Albuterol, Ipratropium Drug Combination
# Alchemilla
# Alcian Blue
# Alcohol Dehydrogenase
# Alcohol Deterrents
# Alcohol Drinking
# Alcohol Oxidoreductases
# Alcoholic Beverages
# Alcohols
# Alcuronium
# Aldehyde Dehydrogenase
# Aldehyde Dehydrogenase, Mitochondrial
# Aldehyde Oxidase
# Aldehyde Oxidoreductases
# Aldehyde Reductase
# Aldehyde-Ketone Transferases
# Aldehyde-Lyases
# Aldehydes
# Aldicarb
# Aldo-Keto Reductase Family 1 Member C2
# Aldo-Keto Reductase Family 1 Member C3
# Aldo-Keto Reductase Family 1 member B10
# Aldo-Keto Reductases
# Aldose-Ketose Isomerases
# Aldosterone
# Aldrin
# Alemtuzumab
# Alendronate
# Aleurites
# Alfaxalone Alfadolone Mixture
# Alfentanil
# Algal Proteins
# Algestone
# Algestone Acetophenide
# Alginates
# Alisma
# Alismataceae
# Alismatales
# AlkB Enzymes
# AlkB Homolog 1, Histone H2a Dioxygenase
# AlkB Homolog 2, Alpha-Ketoglutarate-Dependent Dioxygenase
# AlkB Homolog 3, Alpha-Ketoglutarate-Dependent Dioxygenase
# AlkB Homolog 4, Lysine Demethylase
# AlkB Homolog 5, RNA Demethylase
# AlkB Homolog 8, tRNA Methyltransferase
# Alkadienes
# Alkalies
# Alkaline Ceramidase
# Alkaline Phosphatase
# Alkaloids
# Alkanes
# Alkanesulfonates
# Alkanesulfonic Acids
# Alkenes
# Alkyl and Aryl Transferases
# Alkylating Agents
# Alkylmercury Compounds
# Alkynes
# Allantoin
# Allergens
# Allethrin
# Allium
# Allophanate Hydrolase
# Allopurinol
# Alloxan
# Alloys
# Allyl Compounds
# Allylamine
# Allylestrenol
# Allylglycine
# Allylisopropylacetamide
# Almitrine
# Alnus
# Alocasia
# Aloe
# Alpha Particles
# Alpha-Amanitin
# Alpha-Globulins
# Alpha-Ketoglutarate-Dependent Dioxygenase FTO
# Alphaprodine
# Alpinia
# Alprazolam
# Alprenolol
# Alprostadil
# Alstonia
# Alstroemeria
# Althaea
# Altretamine
# Alum Compounds
# Aluminum
# Aluminum Compounds
# Aluminum Hydroxide
# Aluminum Oxide
# Aluminum Silicates
# Alveolar Bone Grafting
# Alveolar Ridge Augmentation
# Alveolectomy
# Alveoloplasty
# Alzheimer Vaccines
# Amanitins
# Amantadine
# Amaranth Dye
# Amaranthaceae
# Amaranthus
# Amaryllidaceae
# Amaryllidaceae Alkaloids
# Ambenonium Chloride
# Amber
# Ambergris
# Ambrosia
# Ambroxol
# Ambulatory Surgical Procedures
# Amdinocillin
# Amdinocillin Pivoxil
# Amebicides
# Amelogenin
# Americium
# Amide Synthases
# Amides
# Amidine-Lyases
# Amidines
# Amidinotransferases
# Amido Black
# Amidohydrolases
# Amidophosphoribosyltransferase
# Amifostine
# Amikacin
# Amiloride
# Aminacrine
# Amine Oxidase (Copper-Containing)
# Amines
# Amino Acid Chloromethyl Ketones
# Amino Acid Isomerases
# Amino Acid Oxidoreductases
# Amino Acid Transport System A
# Amino Acid Transport System ASC
# Amino Acid Transport System L
# Amino Acid Transport System X-AG
# Amino Acid Transport System y+
# Amino Acid Transport System y+L
# Amino Acid Transport Systems
# Amino Acid Transport Systems, Acidic
# Amino Acid Transport Systems, Basic
# Amino Acid Transport Systems, Neutral
# Amino Acids
# Amino Acids, Acidic
# Amino Acids, Aromatic
# Amino Acids, Basic
# Amino Acids, Branched-Chain
# Amino Acids, Cyclic
# Amino Acids, Diamino
# Amino Acids, Dicarboxylic
# Amino Acids, Essential
# Amino Acids, Neutral
# Amino Acids, Peptides, and Proteins
# Amino Acids, Sulfur
# Amino Acyl-tRNA Synthetases
# Amino Alcohols
# Amino Sugars
# Amino-Acid N-Acetyltransferase
# Aminoacetonitrile
# Aminoacridines
# Aminoacyltransferases
# Aminobenzoates
# Aminobiphenyl Compounds
# Aminobutyrates
# Aminocaproates
# Aminocaproic Acid
# Aminocoumarins
# Aminoethylphosphonic Acid
# Aminoglutethimide
# Aminoglycosides
# Aminohippuric Acids
# Aminohydrolases
# Aminoimidazole Carboxamide
# Aminoisobutyric Acids
# Aminolevulinic Acid
# Aminomethyltransferase
# Aminomuconate-Semialdehyde Dehydrogenase
# Aminooxyacetic Acid
# Aminopeptidases
# Aminophenols
# Aminophylline
# Aminopropionitrile
# Aminopterin
# Aminopyridines
# Aminopyrine
# Aminopyrine N-Demethylase
# Aminoquinolines
# Aminorex
# Aminosalicylic Acid
# Aminosalicylic Acids
# Amiodarone
# Amitriptyline
# Amitrole
# Amlodipine
# Amlodipine Besylate, Olmesartan Medoxomil Drug Combination
# Amlodipine, Valsartan Drug Combination
# Ammi
# Ammonia
# Ammonia-Lyases
# Ammonium Chloride
# Ammonium Compounds
# Ammonium Hydroxide
# Ammonium Sulfate
# Ammotherapy
# Amniocentesis
# Amniotomy
# Amobarbital
# Amodiaquine
# Amomum
# Amorphophallus
# Amoxapine
# Amoxicillin
# Amoxicillin-Potassium Clavulanate Combination
# Ampelopsis
# Amphetamine
# Amphetamines
# Amphibian Proteins
# Amphibian Venoms
# Amphiregulin
# Ampholyte Mixtures
# Amphotericin B
# Ampicillin
# Amplifiers, Electronic
# Amprolium
# Amputation
# Ampyrone
# Amrinone
# Amsacrine
# Amsinckia
# Amsonia
# Amygdalin
# Amyl Nitrite
# Amylases
# Amylin Receptor Agonists
# Amyloid
# Amyloid Precursor Protein Secretases
# Amyloid beta-Peptides
# Amyloid beta-Protein Precursor
# Amyloidogenic Proteins
# Amylopectin
# Amylose
# Anabasine
# Anabolic Agents
# Anacardiaceae
# Anacardic Acids
# Anacardium
# Anagallis
# Analgesia
# Analgesia, Epidural
# Analgesia, Obstetrical
# Analgesia, Patient-Controlled
# Analgesics
# Analgesics, Non-Narcotic
# Analgesics, Opioid
# Analgesics, Short-Acting
# Ananas
# Anaphase-Promoting Complex-Cyclosome
# Anastomosis, Roux-en-Y
# Anastomosis, Surgical
# Ancitabine
# Ancrod
# Androgen Antagonists
# Androgen Receptor Antagonists
# Androgen-Binding Protein
# Androgens
# Andrographis
# Andropogon
# Androstadienes
# Androstane-3,17-diol
# Androstanes
# Androstanols
# Androstatrienes
# Androstenediol
# Androstenediols
# Androstenedione
# Androstenes
# Androstenols
# Androsterone
# Anemarrhena
# Anemone
# Anesthesia
# Anesthesia and Analgesia
# Anesthesia, Cardiac Procedures
# Anesthesia, Caudal
# Anesthesia, Closed-Circuit
# Anesthesia, Conduction
# Anesthesia, Dental
# Anesthesia, Endotracheal
# Anesthesia, Epidural
# Anesthesia, General
# Anesthesia, Inhalation
# Anesthesia, Intravenous
# Anesthesia, Local
# Anesthesia, Obstetrical
# Anesthesia, Rectal
# Anesthesia, Spinal
# Anesthetics
# Anesthetics, Combined
# Anesthetics, Dissociative
# Anesthetics, General
# Anesthetics, Inhalation
# Anesthetics, Intravenous
# Anesthetics, Local
# Anethole Trithione
# Anethum graveolens
# Aneugens
# Angelica
# Angelica archangelica
# Angelica sinensis
# Angiocardiography
# Angiogenesis Inducing Agents
# Angiogenesis Inhibitors
# Angiogenesis Modulating Agents
# Angiogenic Proteins
# Angiography
# Angiography, Digital Subtraction
# Angioplasty
# Angioplasty, Balloon
# Angioplasty, Balloon, Coronary
# Angioplasty, Balloon, Laser-Assisted
# Angioplasty, Laser
# Angiopoietin-1
# Angiopoietin-2
# Angiopoietin-like 4 Protein
# Angiopoietin-like Proteins
# Angiopoietins
# Angioscopes
# Angioscopy
# Angiostatic Proteins
# Angiostatins
# Angiotensin Amide
# Angiotensin I
# Angiotensin II
# Angiotensin II Type 1 Receptor Blockers
# Angiotensin II Type 2 Receptor Blockers
# Angiotensin III
# Angiotensin Receptor Antagonists
# Angiotensin-Converting Enzyme Inhibitors
# Angiotensinogen
# Angiotensins
# Anhydrides
# Anilides
# Aniline Compounds
# Aniline Hydroxylase
# Aniline Mustard
# Anilino Naphthalenesulfonates
# Animal Feed
# Anion Exchange Protein 1, Erythrocyte
# Anion Exchange Resins
# Anion Transport Proteins
# Anions
# Anisoles
# Anisomycin
# Anistreplase
# Ankle Brachial Index
# Ankyrins
# Annexin A1
# Annexin A2
# Annexin A3
# Annexin A4
# Annexin A5
# Annexin A6
# Annexin A7
# Annexins
# Annona
# Annonaceae
# Anoctamin-1
# Anoctamins
# Anonymous Testing
# Anserine
# Ant Venoms
# Antacids
# Antagomirs
# Antazoline
# Antennapedia Homeodomain Protein
# Anterior Cruciate Ligament Reconstruction
# Anterior Temporal Lobectomy
# Anthelmintics
# Anthemis
# Anthocerotophyta
# Anthocyanins
# Anthracenes
# Anthracyclines
# Anthralin
# Anthramycin
# Anthranilate Phosphoribosyltransferase
# Anthranilate Synthase
# Anthraquinones
# Anthrax Vaccines
# Anti-Allergic Agents
# Anti-Anxiety Agents
# Anti-Arrhythmia Agents
# Anti-Asthmatic Agents
# Anti-Bacterial Agents
# Anti-Citrullinated Protein Antibodies
# Anti-Dyskinesia Agents
# Anti-HIV Agents
# Anti-Infective Agents
# Anti-Infective Agents, Local
# Anti-Infective Agents, Urinary
# Anti-Inflammatory Agents
# Anti-Inflammatory Agents, Non-Steroidal
# Anti-Mullerian Hormone
# Anti-Obesity Agents
# Anti-Retroviral Agents
# Anti-Ulcer Agents
# Antiaris
# Antibiotic Prophylaxis
# Antibiotics, Antineoplastic
# Antibiotics, Antitubercular
# Antibodies
# Antibodies, Anti-Idiotypic
# Antibodies, Anticardiolipin
# Antibodies, Antineutrophil Cytoplasmic
# Antibodies, Antinuclear
# Antibodies, Antiphospholipid
# Antibodies, Archaeal
# Antibodies, Bacterial
# Antibodies, Bispecific
# Antibodies, Blocking
# Antibodies, Catalytic
# Antibodies, Fungal
# Antibodies, Helminth
# Antibodies, Heterophile
# Antibodies, Immobilized
# Antibodies, Monoclonal
# Antibodies, Monoclonal, Humanized
# Antibodies, Monoclonal, Murine-Derived
# Antibodies, Neoplasm
# Antibodies, Neutralizing
# Antibodies, Phospho-Specific
# Antibodies, Protozoan
# Antibodies, Viral
# Antibody-Coated Bacteria Test, Urinary
# Anticarcinogenic Agents
# Anticestodal Agents
# Anticholesteremic Agents
# Anticoagulants
# Anticodon
# Anticonvulsants
# Antidepressive Agents
# Antidepressive Agents, Second-Generation
# Antidepressive Agents, Tricyclic
# Antidiarrheals
# Antidiuretic Agents
# Antidiuretic Hormone Receptor Antagonists
# Antidotes
# Antiemetics
# Antifibrinolytic Agents
# Antifoaming Agents
# Antifreeze Proteins
# Antifreeze Proteins, Type I
# Antifreeze Proteins, Type II
# Antifreeze Proteins, Type III
# Antifreeze Proteins, Type IV
# Antifungal Agents
# Antigen-Antibody Complex
# Antigens
# Antigens, Archaeal
# Antigens, Bacterial
# Antigens, CD
# Antigens, CD1
# Antigens, CD19
# Antigens, CD1d
# Antigens, CD20
# Antigens, CD34
# Antigens, CD7

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://id.nlm.nih.gov/mesh/sparql")
sparql.setQuery("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX meshv: <http://id.nlm.nih.gov/mesh/vocab#>
PREFIX mesh: <http://id.nlm.nih.gov/mesh/>
PREFIX mesh2015: <http://id.nlm.nih.gov/mesh/2015/>
PREFIX mesh2016: <http://id.nlm.nih.gov/mesh/2016/>
PREFIX mesh2017: <http://id.nlm.nih.gov/mesh/2017/>
PREFIX mesh2018: <http://id.nlm.nih.gov/mesh/2018/>

SELECT ?d
FROM <http://id.nlm.nih.gov/mesh>
WHERE {
    # ?d a meshv:Concept .
    # ?d rdfs:label 'Aortic Dissection'@en
} 
ORDER BY ?d
""")
sparql.setReturnFormat(JSON)
resultsq = sparql.query()
results = resultsq.convert()
print(results)

for result in results["results"]["bindings"]:
    print(result["d"]["value"])
# Out:
# {'head': {'vars': ['d']}, 'results': {'bindings': [{'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/M000622249'}}]}}
# http://id.nlm.nih.gov/mesh/M000622249

# %%
from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://id.nlm.nih.gov/mesh/sparql")
sparql.setQuery("""
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX meshv: <http://id.nlm.nih.gov/mesh/vocab#>
PREFIX mesh: <http://id.nlm.nih.gov/mesh/>
PREFIX mesh2015: <http://id.nlm.nih.gov/mesh/2015/>
PREFIX mesh2016: <http://id.nlm.nih.gov/mesh/2016/>
PREFIX mesh2017: <http://id.nlm.nih.gov/mesh/2017/>
PREFIX mesh2018: <http://id.nlm.nih.gov/mesh/2018/>

SELECT ?d
FROM <http://id.nlm.nih.gov/mesh>
WHERE {
    # ?d a meshv:Term .
    {?d meshv:prefLabel 'Myocardial Infarction'@en} UNION
    {?d meshv:altLabel 'Myocardial Infarction'@en}
} 
ORDER BY ?d
""")
sparql.setReturnFormat(JSON)
resultsq = sparql.query()
results = resultsq.convert()
print(results)

for result in results["results"]["bindings"]:
    print(result["d"]["value"])
# Out:
# {'head': {'vars': ['d']}, 'results': {'bindings': [{'d': {'type': 'uri', 'value': 'http://id.nlm.nih.gov/mesh/T027447'}}]}}
# http://id.nlm.nih.gov/mesh/T027447
