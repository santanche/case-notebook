# %%
import quilt
quilt.install("santanche/ehealth/mesh/year2018")
from quilt.data.santanche.ehealth import mesh
# Out:
# Downloading package metadata...
#   0%|          | 0.00/1.27M [00:00<?, ?B/s]
# Downloading 1 fragments (1270032 bytes before compression)...
# 100%|██████████| 1.27M/1.27M [00:00<00:00, 2.22MB/s]

# %%
import pandas as pd
df = mesh.year2018()
codeSet = df.loc[df["mesh_heading"] == "Myocardial Infarction"]

code = "none"
if codeSet.size > 0:
    code = codeSet.iat[0,1]

print(code)
# Out:
# C14.280.647.500

# %%
mesh.year2018()
# Out:
#                            mesh_heading                  tree_number
# 0                          Body Regions                          A01
# 1                    Anatomic Landmarks                      A01.111
# 2                                Breast                      A01.236
# 3                 Mammary Glands, Human                  A01.236.249
# 4                               Nipples                  A01.236.500
# 5                           Extremities                      A01.378
# 6                     Amputation Stumps                  A01.378.100
# 7                       Lower Extremity                  A01.378.610
# 8                              Buttocks              A01.378.610.100
# 9                                  Foot              A01.378.610.250
# 10                                Ankle          A01.378.610.250.149
# 11                      Forefoot, Human          A01.378.610.250.300
# 12                           Metatarsus      A01.378.610.250.300.480
# 13                                 Toes      A01.378.610.250.300.792
# 14                               Hallux  A01.378.610.250.300.792.380
# 15                                 Heel          A01.378.610.250.510
# 16                                  Hip              A01.378.610.400
# 17                                 Knee              A01.378.610.450
# 18                                  Leg              A01.378.610.500
# 19                                Thigh              A01.378.610.750
# 20                      Upper Extremity                  A01.378.800
# 21                                  Arm              A01.378.800.075
# 22                               Axilla              A01.378.800.090
# 23                                Elbow              A01.378.800.420
# 24                              Forearm              A01.378.800.585
# 25                                 Hand              A01.378.800.667
# 26                              Fingers          A01.378.800.667.430
# 27                                Thumb      A01.378.800.667.430.705
# 28                           Metacarpus          A01.378.800.667.572
# 29                                Wrist          A01.378.800.667.715
# ...                                 ...                          ...
# 58714                             Haiti              Z01.639.880.425
# 58715                           Jamaica              Z01.639.880.525
# 58716                        Martinique              Z01.639.880.600
# 58717                       Puerto Rico              Z01.639.880.750
# 58718             Saint Kitts and Nevis              Z01.639.880.787
# 58719                       Saint Lucia              Z01.639.880.825
# 58720  Saint Vincent and the Grenadines              Z01.639.880.862
# 58721               Trinidad and Tobago              Z01.639.880.900
# 58722      United States Virgin Islands              Z01.639.880.970
# 58723                           Oceania                      Z01.678
# 58724                       Australasia                  Z01.678.100
# 58725                         Australia              Z01.678.100.373
# 58726      Australian Capital Territory          Z01.678.100.373.500
# 58727                   New South Wales          Z01.678.100.373.750
# 58728                Northern Territory          Z01.678.100.373.875
# 58729                        Queensland          Z01.678.100.373.937
# 58730                   South Australia          Z01.678.100.373.968
# 58731                          Tasmania          Z01.678.100.373.984
# 58732                          Victoria          Z01.678.100.373.992
# 58733                 Western Australia          Z01.678.100.373.996
# 58734                       New Zealand              Z01.678.100.747
# 58735                   Pacific Islands              Z01.678.100.873
# 58736                   Oceans and Seas                      Z01.756
# 58737                    Atlantic Ocean                  Z01.756.092
# 58738                    Gulf of Mexico              Z01.756.092.325
# 58739                         North Sea              Z01.756.092.650
# 58740                         Black Sea                  Z01.756.217
# 58741                      Indian Ocean                  Z01.756.342
# 58742                 Mediterranean Sea                  Z01.756.592
# 58743                     Pacific Ocean                  Z01.756.700
#
# [58744 rows x 2 columns]
